# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# youtube.com/@xperimentallearning

# %%
import pandas as pd
print(f"pandas version : {pd.__version__}")
# Out:
# pandas version : 1.5.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
dates_df = pd.DataFrame({"date":["2017-01-01", "2017-01-09", "2023-01-01"]})
dates_df["date"] = pd.to_datetime(dates_df["date"])
dates_df
# Out:
#         date
# 0 2017-01-01
# 1 2017-01-09
# 2 2023-01-01

# %%
# Expected Output
dates_df["week_number"] = dates_df["date"].dt.isocalendar().week
dates_df
# Out:
#         date  week_number
# 0 2017-01-01           52
# 1 2017-01-09            2
# 2 2023-01-01           52

# %%
dates_df["date"].dt.weekofyear
# Out:
# C:\Users\mohammads6\AppData\Local\Temp\ipykernel_19440\129311345.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   dates_df["date"].dt.weekofyear
# 0    52
# 1     2
# Name: date, dtype: int64

# %%
dates_df["date"].dt.isocalendar().week
# Out:
# 0    52
# 1     2
# 2    52
# Name: week, dtype: UInt32

# %% [markdown]
# ### Reference
# - https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.weekofyear.html
# - https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.isocalendar.html#pandas.Series.dt.isocalendar
