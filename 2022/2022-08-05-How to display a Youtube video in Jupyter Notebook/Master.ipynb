# %% [markdown]
# ## How to display an Youtube Video in Jupyter Notebook

# %%
from IPython.display import YouTubeVideo
# YouTubeVideo('12UZQyJCvXE', width=800, height=300)
YouTubeVideo('12UZQyJCvXE')

# %% [markdown]
# ### Solution
