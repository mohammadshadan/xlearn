# %% [markdown]
# ## How to find the `exact date`, if you know the `Day of Year` and `Year`, using pandas ?

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('12UZQyJCvXE', width=800, height=300)

# %%
from IPython import display
display.Image("Capture.JPG")

# %% [markdown]
# ### Scenario

# %%
import pandas as pd
import numpy as np
print("pandas version :", pd.__version__)
print("numpy version :", np.__version__)
# Out:
# pandas version : 1.3.4
# numpy version : 1.20.3

# %%
d = pd.Series(['189:2022'])
d
# Out:
# 0    189:2022
# dtype: object

# %%
### Expected Output
pd.to_datetime(d, format="%j:%Y")
# Out:
# 0   2022-07-08
# dtype: datetime64[ns]

# %%
### Solution
d_list = pd.Series(['188:2022', '189:2022'])
pd.to_datetime(d_list, format="%j:%Y")
# Out:
# 0   2022-07-07
# 1   2022-07-08
# dtype: datetime64[ns]

# %%
d_list
# Out:
# 0    188:2022
# 1    189:2022
# dtype: object

# %%
Scenario
Expected Output
Solution
