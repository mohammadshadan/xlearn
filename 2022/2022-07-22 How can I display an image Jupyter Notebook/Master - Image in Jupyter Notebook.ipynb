# %% [markdown]
# # How to Add an Image in Jupyter Notebook

# %% [markdown]
# - using IPython display (can show gif)
# - using PIL Image

# %% [markdown]
# ### using IPython display

# %%
from IPython import display

# %%
display.Image("Mickey_Mouse.png")

# %%
display.Image("Convolution_schematic.gif")

# %% [markdown]
# ### using PIL Image

# %%
Image.open("Convolution_schematic.gif")
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=526x384 at 0x202D6B27820>

# %%
ls
# Out:
#  Volume in drive D is DATA
#  Volume Serial Number is E6BF-9675
#
#  Directory of D:\Github\xlearn\2022\2022-07-22 How can I display an image Jupyter Notebook
#
# 07/23/2022  12:08 AM    <DIR>          .
# 07/23/2022  12:08 AM    <DIR>          ..
# 07/22/2022  11:58 PM    <DIR>          .ipynb_checkpoints
# 12/26/2019  10:58 PM             5,506 ChessPawnSpecialMoves.gif
# 12/26/2019  11:52 PM            65,155 Convolution_schematic.gif
# 07/23/2022  12:03 AM         1,706,347 Image in Jupyter Notebook.ipynb
# 12/26/2019  10:27 PM            20,862 Image_1.JPG
# 12/26/2019  11:09 PM                65 links.txt
# 07/23/2022  12:08 AM           105,715 Mickey_Mouse.png
# 12/26/2019  11:06 PM           600,601 tenor.gif
# 12/26/2019  11:08 PM           583,863 tenor_2.gif
# 12/27/2019  12:29 AM         1,707,934 Untitled.ipynb
#                9 File(s)      4,796,048 bytes
#                3 Dir(s)   1,477,898,240 bytes free

# %%
from PIL import Image
Image.open(r"tenor.gif")
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=370x280 at 0x202D6BAA400>

# %%
from PIL import Image
Image.open(r"https://en.wikipedia.org/wiki/Mickey_Mouse#/media/File:Mickey_Mouse.png")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Users\MOHAMM~1\AppData\Local\Temp/ipykernel_40368/2998466276.py in <module>
#       1 from PIL import Image
# ----> 2 Image.open(r"https://en.wikipedia.org/wiki/Mickey_Mouse#/media/File:Mickey_Mouse.png")
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# OSError: [Errno 22] Invalid argument: 'https://en.wikipedia.org/wiki/Mickey_Mouse#/media/File:Mickey_Mouse.png'

# %% [markdown]
# Reference:
# - https://www.geeksforgeeks.org/python-pil-image-show-method/
# - https://ealizadeh.com/blog/3-ways-to-add-images-to-your-jupyter-notebook
