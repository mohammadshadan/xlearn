# %% [markdown]
# # Deploy your Machine Learning model as a REST API on AWS

# %% [markdown]
# from IPython import display
# display.Image("HTTP Error while conda update conda.JPG")
# # conda update conda

# %% [markdown]
# Deploy your `machine learning model`
# - as a REST API
# - using Docker and
# - AWS services like ECR, Sagemaker and Lambda

# %% [markdown]
# - We’ll begin by saving the state of a trained machine learning model, creating inference code and a lightweight server that can be run in a Docker Container.
# - We’ll then deploy the containerized model to ECR and create a machine learning endpoint in Sagemaker.
# - Then we’ll finish off by creating the REST API endpoint.

# %%
from IPython import display
display.Image("HTTP Error while conda install pandas.JPG")
# conda install pandas

# %% [markdown]
# ## Solutions

# %% [markdown]
# - Make sure internet connectivity is there on the system/server
# - Open Anaconda Prompt and run the below command
#  - `conda config --set ssl_verify false`
# - Run again the command for which you were getting the error e.g.
#     - creating new virtual environment in Anaconda `conda create --name env_deeplearning`
#     - updating conda `conda update conda`
#     - installing new package `conda install pandas`
# - `conda config --set ssl_verify true`

# %% [markdown]
# ## Thank You
